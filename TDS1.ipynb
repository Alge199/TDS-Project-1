# %%
import requests
import pandas as pd
import time
import logging
from typing import List, Dict, Any

class GitHubScraper:
    def __init__(self, token: str):
        """
        Initialize the GitHub scraper with your API token.
        
        Args:
            token (str): GitHub Personal Access Token
        """
        self.headers = {
            'Authorization': f'token {token}',
            'Accept': 'application/vnd.github.v3+json'
        }
        self.base_url = 'https://api.github.com'
        
        # Setup logging
        logging.basicConfig(
            level=logging.INFO,
            format='%(asctime)s - %(levelname)s - %(message)s'
        )
        self.logger = logging.getLogger(__name__)

    def _make_request(self, url: str, params: dict = None) -> Dict:
        """
        Make a request to the GitHub API with rate limit handling.
        """
        while True:
            response = requests.get(url, headers=self.headers, params=params)
            
            if response.status_code == 200:
                return response.json()
            elif response.status_code == 403:
                reset_time = int(response.headers.get('X-RateLimit-Reset', 0))
                sleep_time = max(reset_time - time.time(), 0) + 1
                self.logger.warning(f"Rate limit hit. Sleeping for {sleep_time} seconds")
                time.sleep(sleep_time)
            else:
                self.logger.error(f"Error {response.status_code}: {response.text}")
                response.raise_for_status()

    def clean_company_name(self, company: str) -> str:
        """
        Clean up company names according to specifications.
        """
        if not company:
            return ""
        
        # Strip whitespace and @ symbol
        cleaned = company.strip().lstrip('@')
        
        # Convert to uppercase
        return cleaned.upper()

    def search_users(self, location: str, min_followers: int) -> List[Dict]:
        """
        Search for GitHub users in a specific location with minimum followers.
        """
        users = []
        page = 1
        
        while True:
            self.logger.info(f"Fetching users page {page}")
            
            query = f"location:{location} followers:>={min_followers}"
            params = {
                'q': query,
                'per_page': 100,
                'page': page
            }
            
            url = f"{self.base_url}/search/users"
            response = self._make_request(url, params)
            
            if not response['items']:
                break
                
            for user in response['items']:
                user_data = self._make_request(user['url'])
                
                # Extract only the required fields with exact matching names
                cleaned_data = {
                    'login': user_data['login'],
                    'name': user_data['name'] if user_data['name'] else "",
                    'company': self.clean_company_name(user_data.get('company')),
                    'location': user_data['location'] if user_data['location'] else "",
                    'email': user_data['email'] if user_data['email'] else "",
                    'hireable': user_data['hireable'] if user_data['hireable'] is not None else False,
                    'bio': user_data['bio'] if user_data['bio'] else "",
                    'public_repos': user_data['public_repos'],
                    'followers': user_data['followers'],
                    'following': user_data['following'],
                    'created_at': user_data['created_at']
                }
                
                users.append(cleaned_data)
                
            page += 1
            
        return users

    def get_user_repositories(self, username: str, max_repos: int = 500) -> List[Dict]:
        """
        Get repositories for a specific user.
        """
        repos = []
        page = 1
        
        while len(repos) < max_repos:
            self.logger.info(f"Fetching repositories for {username}, page {page}")
            
            params = {
                'sort': 'pushed',
                'direction': 'desc',
                'per_page': 100,
                'page': page
            }
            
            url = f"{self.base_url}/users/{username}/repos"
            response = self._make_request(url, params)
            
            if not response:
                break
                
            for repo in response:
                # Extract only the required fields with exact matching names
                repo_data = {
                    'login': username,  # Adding owner's login as required
                    'full_name': repo['full_name'],
                    'created_at': repo['created_at'],
                    'stargazers_count': repo['stargazers_count'],
                    'watchers_count': repo['watchers_count'],
                    'language': repo['language'] if repo['language'] else "",
                    'has_projects': repo['has_projects'],
                    'has_wiki': repo['has_wiki'],
                    'license_name': repo['license']['key'] if repo.get('license') else ""
                }
                
                repos.append(repo_data)
                
            if len(response) < 100:
                break
                
            page += 1
            
        return repos[:max_repos]

def main():
    # Get GitHub token
    token = input("Enter your GitHub token: ").strip()
    if not token:
        print("Token is required. Exiting...")
        return

    # Initialize scraper
    scraper = GitHubScraper(token)
    
    # Search for users in Delhi with >100 followers
    users = scraper.search_users(location='melbourne', min_followers=100)
    
    # Save users to CSV
    users_df = pd.DataFrame(users)
    users_df.to_csv('users.csv', index=False)
    
    # Get repositories for each user
    all_repos = []
    for user in users:
        repos = scraper.get_user_repositories(user['login'])
        all_repos.extend(repos)
    
    # Save repositories to CSV
    repos_df = pd.DataFrame(all_repos)
    repos_df.to_csv('repositories.csv', index=False)
    
    print(f"Scraped {len(users)} users and {len(all_repos)} repositories")
    
    # Create README.md
    with open('README.md', 'w') as f:
        f.write(f"""# GitHub Users in melbourne

This repository contains data about GitHub users in melbourne with over 100 followers and their repositories.

## Files

1. `users.csv`: Contains information about {len(users)} GitHub users in melbourne with over 100 followers
2. `repositories.csv`: Contains information about {len(all_repos)} public repositories from these users
3. `gitscrap.py`: Python script used to collect this data

## Data Collection

- Data collected using GitHub API
- Date of collection: {time.strftime('%Y-%m-%d')}
- Only included users with 100+ followers
- Up to 500 most recently pushed repositories per user
""")

if __name__ == "__main__":
    main()
# Out:
# Enter your GitHub token:  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
# 2024-10-30 15:42:48,589 - INFO - Fetching users page 1
# 2024-10-30 15:44:10,326 - INFO - Fetching users page 2
# 2024-10-30 15:45:31,300 - INFO - Fetching users page 3
# 2024-10-30 15:46:54,275 - INFO - Fetching users page 4
# 2024-10-30 15:47:25,423 - INFO - Fetching users page 5
# 2024-10-30 15:47:26,260 - INFO - Fetching repositories for mosh-hamedani, page 1
# 2024-10-30 15:47:27,212 - INFO - Fetching repositories for TheCherno, page 1
# 2024-10-30 15:47:28,314 - INFO - Fetching repositories for haileys, page 1
# 2024-10-30 15:47:29,884 - INFO - Fetching repositories for haileys, page 2
# 2024-10-30 15:47:31,796 - INFO - Fetching repositories for haileys, page 3
# 2024-10-30 15:47:33,216 - INFO - Fetching repositories for haileys, page 4
# 2024-10-30 15:47:34,659 - INFO - Fetching repositories for rstacruz, page 1
# 2024-10-30 15:47:36,603 - INFO - Fetching repositories for rstacruz, page 2
# 2024-10-30 15:47:39,087 - INFO - Fetching repositories for rstacruz, page 3
# 2024-10-30 15:47:40,519 - INFO - Fetching repositories for rstacruz, page 4
# 2024-10-30 15:47:42,534 - INFO - Fetching repositories for rstacruz, page 5
# 2024-10-30 15:47:44,177 - INFO - Fetching repositories for jesseduffield, page 1
# 2024-10-30 15:47:45,668 - INFO - Fetching repositories for basarat, page 1
# 2024-10-30 15:47:47,378 - INFO - Fetching repositories for basarat, page 2
# 2024-10-30 15:47:48,907 - INFO - Fetching repositories for basarat, page 3
# 2024-10-30 15:47:50,315 - INFO - Fetching repositories for basarat, page 4
# 2024-10-30 15:47:52,334 - INFO - Fetching repositories for basarat, page 5
# 2024-10-30 15:47:53,493 - INFO - Fetching repositories for markdalgleish, page 1
# 2024-10-30 15:47:54,974 - INFO - Fetching repositories for markdalgleish, page 2
# 2024-10-30 15:47:56,443 - INFO - Fetching repositories for markdalgleish, page 3
# 2024-10-30 15:47:58,823 - INFO - Fetching repositories for JakeLin, page 1
# 2024-10-30 15:48:00,162 - INFO - Fetching repositories for binarythistle, page 1
# 2024-10-30 15:48:01,302 - INFO - Fetching repositories for radar, page 1
# 2024-10-30 15:48:02,766 - INFO - Fetching repositories for radar, page 2
# 2024-10-30 15:48:07,000 - INFO - Fetching repositories for radar, page 3
# 2024-10-30 15:48:08,075 - INFO - Fetching repositories for mishmanners, page 1
# 2024-10-30 15:48:12,642 - INFO - Fetching repositories for mishmanners, page 2
# 2024-10-30 15:48:13,719 - INFO - Fetching repositories for timacdonald, page 1
# 2024-10-30 15:48:14,935 - INFO - Fetching repositories for TuPayChain, page 1
# 2024-10-30 15:48:15,772 - INFO - Fetching repositories for md-5, page 1
# 2024-10-30 15:48:18,568 - INFO - Fetching repositories for md-5, page 2
# 2024-10-30 15:48:20,210 - INFO - Fetching repositories for thomasdavis, page 1
# 2024-10-30 15:48:22,676 - INFO - Fetching repositories for thomasdavis, page 2
# 2024-10-30 15:48:23,979 - INFO - Fetching repositories for geelen, page 1
# 2024-10-30 15:48:26,821 - INFO - Fetching repositories for geelen, page 2
# 2024-10-30 15:48:28,490 - INFO - Fetching repositories for geelen, page 3
# 2024-10-30 15:48:29,650 - INFO - Fetching repositories for MugunthKumar, page 1
# 2024-10-30 15:48:30,713 - INFO - Fetching repositories for tseemann, page 1
# 2024-10-30 15:48:32,568 - INFO - Fetching repositories for tseemann, page 2
# 2024-10-30 15:48:33,701 - INFO - Fetching repositories for loftwah, page 1
# 2024-10-30 15:48:35,983 - INFO - Fetching repositories for loftwah, page 2
# 2024-10-30 15:48:38,453 - INFO - Fetching repositories for loftwah, page 3
# 2024-10-30 15:48:41,560 - INFO - Fetching repositories for loftwah, page 4
# 2024-10-30 15:48:42,652 - INFO - Fetching repositories for rogerclarkmelbourne, page 1
# 2024-10-30 15:48:43,557 - INFO - Fetching repositories for jxom, page 1
# 2024-10-30 15:48:45,217 - INFO - Fetching repositories for jxom, page 2
# 2024-10-30 15:48:46,586 - INFO - Fetching repositories for rrwick, page 1
# 2024-10-30 15:48:47,805 - INFO - Fetching repositories for abruzzi, page 1
# 2024-10-30 15:48:49,575 - INFO - Fetching repositories for abruzzi, page 2
# 2024-10-30 15:48:51,671 - INFO - Fetching repositories for abruzzi, page 3
# 2024-10-30 15:48:54,333 - INFO - Fetching repositories for abruzzi, page 4
# 2024-10-30 15:48:55,191 - INFO - Fetching repositories for kitsonk, page 1
# 2024-10-30 15:48:58,372 - INFO - Fetching repositories for kitsonk, page 2
# 2024-10-30 15:48:59,568 - INFO - Fetching repositories for mattgallagher, page 1
# 2024-10-30 15:49:00,464 - INFO - Fetching repositories for sidorares, page 1
# 2024-10-30 15:49:03,332 - INFO - Fetching repositories for sidorares, page 2
# 2024-10-30 15:49:08,787 - INFO - Fetching repositories for benschwarz, page 1
# 2024-10-30 15:49:10,584 - INFO - Fetching repositories for benschwarz, page 2
# 2024-10-30 15:49:11,528 - INFO - Fetching repositories for philnash, page 1
# 2024-10-30 15:49:13,059 - INFO - Fetching repositories for philnash, page 2
# 2024-10-30 15:49:15,052 - INFO - Fetching repositories for philnash, page 3
# 2024-10-30 15:49:16,683 - INFO - Fetching repositories for philnash, page 4
# 2024-10-30 15:49:17,561 - INFO - Fetching repositories for Viralmaniar, page 1
# 2024-10-30 15:49:19,582 - INFO - Fetching repositories for iancoleman, page 1
# 2024-10-30 15:49:21,962 - INFO - Fetching repositories for brendanzab, page 1
# 2024-10-30 15:49:23,407 - INFO - Fetching repositories for brendanzab, page 2
# 2024-10-30 15:49:24,363 - INFO - Fetching repositories for dpgeorge, page 1
# 2024-10-30 15:49:25,334 - INFO - Fetching repositories for tmeasday, page 1
# 2024-10-30 15:49:30,690 - INFO - Fetching repositories for tmeasday, page 2
# 2024-10-30 15:49:32,163 - INFO - Fetching repositories for tmeasday, page 3
# 2024-10-30 15:49:33,636 - INFO - Fetching repositories for tmeasday, page 4
# 2024-10-30 15:49:35,008 - INFO - Fetching repositories for Expensify, page 1
# 2024-10-30 15:49:36,209 - INFO - Fetching repositories for AliasIO, page 1
# 2024-10-30 15:49:37,077 - INFO - Fetching repositories for jcouyang, page 1
# 2024-10-30 15:49:38,574 - INFO - Fetching repositories for jcouyang, page 2
# 2024-10-30 15:49:40,528 - INFO - Fetching repositories for kivikakk, page 1
# 2024-10-30 15:49:41,776 - INFO - Fetching repositories for nnethercote, page 1
# 2024-10-30 15:49:43,116 - INFO - Fetching repositories for jaydenseric, page 1
# 2024-10-30 15:49:44,519 - INFO - Fetching repositories for jaydenseric, page 2
# 2024-10-30 15:49:45,381 - INFO - Fetching repositories for ryanseddon, page 1
# 2024-10-30 15:49:46,709 - INFO - Fetching repositories for ryanseddon, page 2
# 2024-10-30 15:49:47,511 - INFO - Fetching repositories for initstring, page 1
# 2024-10-30 15:49:48,545 - INFO - Fetching repositories for Anon-Exploiter, page 1
# 2024-10-30 15:49:51,149 - INFO - Fetching repositories for Anon-Exploiter, page 2
# 2024-10-30 15:49:52,162 - INFO - Fetching repositories for bardiharborow, page 1
# 2024-10-30 15:49:53,180 - INFO - Fetching repositories for xaviershay, page 1
# 2024-10-30 15:49:54,482 - INFO - Fetching repositories for xaviershay, page 2
# 2024-10-30 15:49:55,929 - INFO - Fetching repositories for xaviershay, page 3
# 2024-10-30 15:49:56,890 - INFO - Fetching repositories for elliotcondon, page 1
# 2024-10-30 15:49:57,675 - INFO - Fetching repositories for dicook, page 1
# 2024-10-30 15:49:59,080 - INFO - Fetching repositories for Karolyna84, page 1
# 2024-10-30 15:50:00,271 - INFO - Fetching repositories for priseborough, page 1
# 2024-10-30 15:50:01,170 - INFO - Fetching repositories for wahyd4, page 1
# 2024-10-30 15:50:03,985 - INFO - Fetching repositories for wahyd4, page 2
# 2024-10-30 15:50:05,118 - INFO - Fetching repositories for drewnoakes, page 1
# 2024-10-30 15:50:07,094 - INFO - Fetching repositories for drewnoakes, page 2
# 2024-10-30 15:50:08,357 - INFO - Fetching repositories for wireghoul, page 1
# 2024-10-30 15:50:09,642 - INFO - Fetching repositories for pat, page 1
# 2024-10-30 15:50:13,537 - INFO - Fetching repositories for pat, page 2
# 2024-10-30 15:50:15,169 - INFO - Fetching repositories for pat, page 3
# 2024-10-30 15:50:16,057 - INFO - Fetching repositories for abolkog, page 1
# 2024-10-30 15:50:17,059 - INFO - Fetching repositories for fraserxu, page 1
# 2024-10-30 15:50:19,697 - INFO - Fetching repositories for fraserxu, page 2
# 2024-10-30 15:50:21,492 - INFO - Fetching repositories for mokagio, page 1
# 2024-10-30 15:50:24,164 - INFO - Fetching repositories for mokagio, page 2
# 2024-10-30 15:50:26,427 - INFO - Fetching repositories for mokagio, page 3
# 2024-10-30 15:50:28,359 - INFO - Fetching repositories for trevorstephens, page 1
# 2024-10-30 15:50:29,247 - INFO - Fetching repositories for amanda08, page 1
# 2024-10-30 15:50:30,132 - INFO - Fetching repositories for toolmantim, page 1
# 2024-10-30 15:50:31,543 - INFO - Fetching repositories for toolmantim, page 2
# 2024-10-30 15:50:32,457 - INFO - Fetching repositories for daurnimator, page 1
# 2024-10-30 15:50:34,436 - INFO - Fetching repositories for daurnimator, page 2
# 2024-10-30 15:50:35,587 - INFO - Fetching repositories for mitchmindtree, page 1
# 2024-10-30 15:50:38,712 - INFO - Fetching repositories for mitchmindtree, page 2
# 2024-10-30 15:50:40,262 - INFO - Fetching repositories for mitchmindtree, page 3
# 2024-10-30 15:50:41,447 - INFO - Fetching repositories for hamishwillee, page 1
# 2024-10-30 15:50:42,981 - INFO - Fetching repositories for hamishwillee, page 2
# 2024-10-30 15:50:43,938 - INFO - Fetching repositories for kolber, page 1
# 2024-10-30 15:50:45,043 - INFO - Fetching repositories for joho, page 1
# 2024-10-30 15:50:46,233 - INFO - Fetching repositories for hugomd, page 1
# 2024-10-30 15:50:47,543 - INFO - Fetching repositories for hugomd, page 2
# 2024-10-30 15:50:48,740 - INFO - Fetching repositories for UnexpectedMaker, page 1
# 2024-10-30 15:50:49,916 - INFO - Fetching repositories for merill, page 1
# 2024-10-30 15:50:51,150 - INFO - Fetching repositories for jagregory, page 1
# 2024-10-30 15:50:52,787 - INFO - Fetching repositories for jagregory, page 2
# 2024-10-30 15:50:54,055 - INFO - Fetching repositories for moroshko, page 1
# 2024-10-30 15:50:55,955 - INFO - Fetching repositories for moroshko, page 2
# 2024-10-30 15:50:57,316 - INFO - Fetching repositories for davkean, page 1
# 2024-10-30 15:50:58,805 - INFO - Fetching repositories for jni, page 1
# 2024-10-30 15:51:00,250 - INFO - Fetching repositories for jni, page 2
# 2024-10-30 15:51:01,659 - INFO - Fetching repositories for jni, page 3
# 2024-10-30 15:51:03,049 - INFO - Fetching repositories for jni, page 4
# 2024-10-30 15:51:03,921 - INFO - Fetching repositories for chendo, page 1
# 2024-10-30 15:51:05,653 - INFO - Fetching repositories for chendo, page 2
# 2024-10-30 15:51:07,087 - INFO - Fetching repositories for chendo, page 3
# 2024-10-30 15:51:08,077 - INFO - Fetching repositories for Benjamin-Dobell, page 1
# 2024-10-30 15:51:09,747 - INFO - Fetching repositories for Benjamin-Dobell, page 2
# 2024-10-30 15:51:11,237 - INFO - Fetching repositories for justinsteven, page 1
# 2024-10-30 15:51:12,597 - INFO - Fetching repositories for nickgammon, page 1
# 2024-10-30 15:51:13,530 - INFO - Fetching repositories for evgenyneu, page 1
# 2024-10-30 15:51:15,185 - INFO - Fetching repositories for evgenyneu, page 2
# 2024-10-30 15:51:16,086 - INFO - Fetching repositories for azz, page 1
# 2024-10-30 15:51:18,674 - INFO - Fetching repositories for azz, page 2
# 2024-10-30 15:51:20,179 - INFO - Fetching repositories for taitems, page 1
# 2024-10-30 15:51:22,072 - INFO - Fetching repositories for alexhude, page 1
# 2024-10-30 15:51:23,107 - INFO - Fetching repositories for waferbaby, page 1
# 2024-10-30 15:51:23,937 - INFO - Fetching repositories for Sutto, page 1
# 2024-10-30 15:51:26,296 - INFO - Fetching repositories for Sutto, page 2
# 2024-10-30 15:51:27,323 - INFO - Fetching repositories for chrisleekr, page 1
# 2024-10-30 15:51:28,258 - INFO - Fetching repositories for aidansteele, page 1
# 2024-10-30 15:51:29,584 - INFO - Fetching repositories for aidansteele, page 2
# 2024-10-30 15:51:31,237 - INFO - Fetching repositories for sj26, page 1
# 2024-10-30 15:51:32,804 - INFO - Fetching repositories for sj26, page 2
# 2024-10-30 15:51:35,765 - INFO - Fetching repositories for sj26, page 3
# 2024-10-30 15:51:37,289 - INFO - Fetching repositories for sj26, page 4
# 2024-10-30 15:51:38,542 - INFO - Fetching repositories for justinfrench, page 1
# 2024-10-30 15:51:39,469 - INFO - Fetching repositories for vektah, page 1
# 2024-10-30 15:51:40,793 - INFO - Fetching repositories for aaronparker, page 1
# 2024-10-30 15:51:41,848 - INFO - Fetching repositories for aershov24, page 1
# 2024-10-30 15:51:42,964 - INFO - Fetching repositories for wolfeidau, page 1
# 2024-10-30 15:51:45,349 - INFO - Fetching repositories for wolfeidau, page 2
# 2024-10-30 15:51:47,539 - INFO - Fetching repositories for wolfeidau, page 3
# 2024-10-30 15:51:49,236 - INFO - Fetching repositories for wolfeidau, page 4
# 2024-10-30 15:51:51,883 - INFO - Fetching repositories for wolfeidau, page 5
# 2024-10-30 15:51:53,435 - INFO - Fetching repositories for eugeneware, page 1
# 2024-10-30 15:51:55,862 - INFO - Fetching repositories for eugeneware, page 2
# 2024-10-30 15:51:58,071 - INFO - Fetching repositories for eugeneware, page 3
# 2024-10-30 15:51:59,169 - INFO - Fetching repositories for deoxxa, page 1
# 2024-10-30 15:52:01,563 - INFO - Fetching repositories for deoxxa, page 2
# 2024-10-30 15:52:02,950 - INFO - Fetching repositories for deoxxa, page 3
# 2024-10-30 15:52:05,027 - INFO - Fetching repositories for deoxxa, page 4
# 2024-10-30 15:52:06,220 - INFO - Fetching repositories for Rosuav, page 1
# 2024-10-30 15:52:08,443 - INFO - Fetching repositories for Rosuav, page 2
# 2024-10-30 15:52:10,699 - INFO - Fetching repositories for Rosuav, page 3
# 2024-10-30 15:52:11,588 - INFO - Fetching repositories for tabs-not-spaces, page 1
# 2024-10-30 15:52:13,078 - INFO - Fetching repositories for tabs-not-spaces, page 2
# 2024-10-30 15:52:13,916 - INFO - Fetching repositories for ihadeed, page 1
# 2024-10-30 15:52:16,783 - INFO - Fetching repositories for ihadeed, page 2
# 2024-10-30 15:52:18,033 - INFO - Fetching repositories for edhinrichsen, page 1
# 2024-10-30 15:52:18,863 - INFO - Fetching repositories for RManLuo, page 1
# 2024-10-30 15:52:20,203 - INFO - Fetching repositories for AndiiCodes, page 1
# 2024-10-30 15:52:21,046 - INFO - Fetching repositories for rfk, page 1
# 2024-10-30 15:52:22,290 - INFO - Fetching repositories for srikat, page 1
# 2024-10-30 15:52:24,331 - INFO - Fetching repositories for devgeeks, page 1
# 2024-10-30 15:52:27,505 - INFO - Fetching repositories for joshwnj, page 1
# 2024-10-30 15:52:30,666 - INFO - Fetching repositories for joshwnj, page 2
# 2024-10-30 15:52:32,575 - INFO - Fetching repositories for andyyhope, page 1
# 2024-10-30 15:52:33,534 - INFO - Fetching repositories for KaelWD, page 1
# 2024-10-30 15:52:34,703 - INFO - Fetching repositories for psifertex, page 1
# 2024-10-30 15:52:36,176 - INFO - Fetching repositories for psifertex, page 2
# 2024-10-30 15:52:37,098 - INFO - Fetching repositories for alanjrogers, page 1
# 2024-10-30 15:52:38,176 - INFO - Fetching repositories for pact-foundation, page 1
# 2024-10-30 15:52:39,630 - INFO - Fetching repositories for pjf, page 1
# 2024-10-30 15:52:41,151 - INFO - Fetching repositories for pjf, page 2
# 2024-10-30 15:52:42,219 - INFO - Fetching repositories for brainstorm, page 1
# 2024-10-30 15:52:44,515 - INFO - Fetching repositories for dekz, page 1
# 2024-10-30 15:52:45,824 - INFO - Fetching repositories for dekz, page 2
# 2024-10-30 15:52:47,270 - INFO - Fetching repositories for mohammadKarimi, page 1
# 2024-10-30 15:52:48,126 - INFO - Fetching repositories for lox, page 1
# 2024-10-30 15:52:49,704 - INFO - Fetching repositories for abcminiuser, page 1
# 2024-10-30 15:52:50,820 - INFO - Fetching repositories for sbarski, page 1
# 2024-10-30 15:52:52,179 - INFO - Fetching repositories for timusus, page 1
# 2024-10-30 15:52:53,311 - INFO - Fetching repositories for jonoxer, page 1
# 2024-10-30 15:52:54,307 - INFO - Fetching repositories for ntwb, page 1
# 2024-10-30 15:53:45,105 - INFO - Fetching repositories for navidcy, page 1
# 2024-10-30 15:53:47,820 - INFO - Fetching repositories for navidcy, page 2
# 2024-10-30 15:53:49,542 - INFO - Fetching repositories for lachlanhardy, page 1
# 2024-10-30 15:53:50,576 - INFO - Fetching repositories for mefellows, page 1
# 2024-10-30 15:53:52,061 - INFO - Fetching repositories for mefellows, page 2
# 2024-10-30 15:53:53,220 - INFO - Fetching repositories for djmdjm, page 1
# 2024-10-30 15:53:54,347 - INFO - Fetching repositories for yob, page 1
# 2024-10-30 15:53:56,175 - INFO - Fetching repositories for yob, page 2
# 2024-10-30 15:53:57,808 - INFO - Fetching repositories for grahamegrieve, page 1
# 2024-10-30 15:53:59,132 - INFO - Fetching repositories for dhotson, page 1
# 2024-10-30 15:54:00,300 - INFO - Fetching repositories for arttnba3, page 1
# 2024-10-30 15:54:01,279 - INFO - Fetching repositories for Mair, page 1
# 2024-10-30 15:54:02,359 - INFO - Fetching repositories for xiaodaigh, page 1
# 2024-10-30 15:54:05,020 - INFO - Fetching repositories for xiaodaigh, page 2
# 2024-10-30 15:54:05,890 - INFO - Fetching repositories for ychescale9, page 1
# 2024-10-30 15:54:06,961 - INFO - Fetching repositories for dipjyotimetia, page 1
# 2024-10-30 15:54:10,007 - INFO - Fetching repositories for dipjyotimetia, page 2
# 2024-10-30 15:54:11,974 - INFO - Fetching repositories for dipjyotimetia, page 3
# 2024-10-30 15:54:15,181 - INFO - Fetching repositories for dipjyotimetia, page 4
# 2024-10-30 15:54:16,989 - INFO - Fetching repositories for dipjyotimetia, page 5
# 2024-10-30 15:54:18,221 - INFO - Fetching repositories for DWilliames, page 1
# 2024-10-30 15:54:19,273 - INFO - Fetching repositories for 0neSe7en, page 1
# 2024-10-30 15:54:20,797 - INFO - Fetching repositories for 0neSe7en, page 2
# 2024-10-30 15:54:21,620 - INFO - Fetching repositories for ACloudGuru, page 1
# 2024-10-30 15:54:23,115 - INFO - Fetching repositories for mikefarah, page 1
# 2024-10-30 15:54:24,208 - INFO - Fetching repositories for mihar-22, page 1
# 2024-10-30 15:54:25,169 - INFO - Fetching repositories for davidwengier, page 1
# 2024-10-30 15:54:28,107 - INFO - Fetching repositories for davidwengier, page 2
# 2024-10-30 15:54:28,959 - INFO - Fetching repositories for stevage, page 1
# 2024-10-30 15:54:30,400 - INFO - Fetching repositories for stevage, page 2
# 2024-10-30 15:54:31,928 - INFO - Fetching repositories for stevage, page 3
# 2024-10-30 15:54:32,987 - INFO - Fetching repositories for crafterm, page 1
# 2024-10-30 15:54:33,951 - INFO - Fetching repositories for tomdalling, page 1
# 2024-10-30 15:54:35,228 - INFO - Fetching repositories for adammurdoch, page 1
# 2024-10-30 15:54:36,750 - INFO - Fetching repositories for maks, page 1
# 2024-10-30 15:54:39,145 - INFO - Fetching repositories for maks, page 2
# 2024-10-30 15:54:41,355 - INFO - Fetching repositories for maks, page 3
# 2024-10-30 15:54:43,534 - INFO - Fetching repositories for maks, page 4
# 2024-10-30 15:54:45,203 - INFO - Fetching repositories for jessedc, page 1
# 2024-10-30 15:54:47,493 - INFO - Fetching repositories for 99designs, page 1
# 2024-10-30 15:54:48,996 - INFO - Fetching repositories for jarshwah, page 1
# 2024-10-30 15:54:50,253 - INFO - Fetching repositories for varund7726, page 1
# 2024-10-30 15:54:51,563 - INFO - Fetching repositories for domesticcatsoftware, page 1
# 2024-10-30 15:54:52,409 - INFO - Fetching repositories for mblode, page 1
# 2024-10-30 15:54:53,771 - INFO - Fetching repositories for mblode, page 2
# 2024-10-30 15:54:54,704 - INFO - Fetching repositories for KelvinJin, page 1
# 2024-10-30 15:54:55,905 - INFO - Fetching repositories for vinhphunguyen, page 1
# 2024-10-30 15:54:56,867 - INFO - Fetching repositories for jeromyanglim, page 1
# 2024-10-30 15:54:58,021 - INFO - Fetching repositories for chris-horner, page 1
# 2024-10-30 15:54:59,022 - INFO - Fetching repositories for SEEK-Jobs, page 1
# 2024-10-30 15:54:59,812 - INFO - Fetching repositories for magnetikonline, page 1
# 2024-10-30 15:55:01,851 - INFO - Fetching repositories for mattnotmax, page 1
# 2024-10-30 15:55:02,988 - INFO - Fetching repositories for feit-comp30023-2024, page 1
# 2024-10-30 15:55:03,785 - INFO - Fetching repositories for sammcj, page 1
# 2024-10-30 15:55:05,363 - INFO - Fetching repositories for sammcj, page 2
# 2024-10-30 15:55:06,659 - INFO - Fetching repositories for nathanielw, page 1
# 2024-10-30 15:55:08,430 - INFO - Fetching repositories for neekey, page 1
# 2024-10-30 15:55:09,849 - INFO - Fetching repositories for neekey, page 2
# 2024-10-30 15:55:10,990 - INFO - Fetching repositories for jimjam-slam, page 1
# 2024-10-30 15:55:12,338 - INFO - Fetching repositories for mukul500, page 1
# 2024-10-30 15:55:13,347 - INFO - Fetching repositories for ash47, page 1
# 2024-10-30 15:55:14,571 - INFO - Fetching repositories for rmit-computing-technologies, page 1
# 2024-10-30 15:55:15,423 - INFO - Fetching repositories for MattCowgill, page 1
# 2024-10-30 15:55:16,848 - INFO - Fetching repositories for benbarsdell, page 1
# 2024-10-30 15:55:17,764 - INFO - Fetching repositories for bcgit, page 1
# 2024-10-30 15:55:18,750 - INFO - Fetching repositories for willvelida, page 1
# 2024-10-30 15:55:20,859 - INFO - Fetching repositories for willvelida, page 2
# 2024-10-30 15:55:22,358 - INFO - Fetching repositories for willvelida, page 3
# 2024-10-30 15:55:24,170 - INFO - Fetching repositories for ericjiang97, page 1
# 2024-10-30 15:55:25,751 - INFO - Fetching repositories for ericjiang97, page 2
# 2024-10-30 15:55:26,850 - INFO - Fetching repositories for kmkurn, page 1
# 2024-10-30 15:55:28,996 - INFO - Fetching repositories for ajfisher, page 1
# 2024-10-30 15:55:30,167 - INFO - Fetching repositories for glennawatson, page 1
# 2024-10-30 15:55:31,513 - INFO - Fetching repositories for ldiebold, page 1
# 2024-10-30 15:56:29,079 - INFO - Fetching repositories for bungnoid, page 1
# 2024-10-30 15:56:30,128 - INFO - Fetching repositories for skoval, page 1
# 2024-10-30 15:56:31,299 - INFO - Fetching repositories for prodigysml, page 1
# 2024-10-30 15:56:32,710 - INFO - Fetching repositories for JacksonBates, page 1
# 2024-10-30 15:56:35,289 - INFO - Fetching repositories for plasticine, page 1
# 2024-10-30 15:56:37,085 - INFO - Fetching repositories for plasticine, page 2
# 2024-10-30 15:56:38,888 - INFO - Fetching repositories for timbertson, page 1
# 2024-10-30 15:56:40,993 - INFO - Fetching repositories for timbertson, page 2
# 2024-10-30 15:56:43,058 - INFO - Fetching repositories for timbertson, page 3
# 2024-10-30 15:56:44,109 - INFO - Fetching repositories for NullTerminatorr, page 1
# 2024-10-30 15:56:44,995 - INFO - Fetching repositories for julia-, page 1
# 2024-10-30 15:56:46,755 - INFO - Fetching repositories for ibracorp, page 1
# 2024-10-30 15:56:47,663 - INFO - Fetching repositories for mariovisic, page 1
# 2024-10-30 15:56:50,560 - INFO - Fetching repositories for JaseZiv, page 1
# 2024-10-30 15:56:52,062 - INFO - Fetching repositories for mdneuzerling, page 1
# 2024-10-30 15:56:53,782 - INFO - Fetching repositories for minghao-wu, page 1
# 2024-10-30 15:56:54,765 - INFO - Fetching repositories for DavidArayan, page 1
# 2024-10-30 15:56:55,735 - INFO - Fetching repositories for loklaan, page 1
# 2024-10-30 15:56:57,138 - INFO - Fetching repositories for loklaan, page 2
# 2024-10-30 15:56:57,926 - INFO - Fetching repositories for DanielThomas, page 1
# 2024-10-30 15:56:59,269 - INFO - Fetching repositories for learntodroid, page 1
# 2024-10-30 15:57:00,427 - INFO - Fetching repositories for eliotharper, page 1
# 2024-10-30 15:57:01,338 - INFO - Fetching repositories for philipbelesky, page 1
# 2024-10-30 15:57:02,764 - INFO - Fetching repositories for emilytrau, page 1
# 2024-10-30 15:57:03,925 - INFO - Fetching repositories for josh-, page 1
# 2024-10-30 15:57:05,189 - INFO - Fetching repositories for KieraDOG, page 1
# 2024-10-30 15:57:06,308 - INFO - Fetching repositories for mutoo, page 1
# 2024-10-30 15:57:07,401 - INFO - Fetching repositories for harsilspatel, page 1
# 2024-10-30 15:57:08,407 - INFO - Fetching repositories for mitchdenny, page 1
# 2024-10-30 15:57:11,187 - INFO - Fetching repositories for mitchdenny, page 2
# 2024-10-30 15:57:14,099 - INFO - Fetching repositories for martinbjeldbak, page 1
# 2024-10-30 15:57:15,229 - INFO - Fetching repositories for jmattsson, page 1
# 2024-10-30 15:57:17,066 - INFO - Fetching repositories for lvjian700, page 1
# 2024-10-30 15:57:18,704 - INFO - Fetching repositories for plutext, page 1
# 2024-10-30 15:57:20,892 - INFO - Fetching repositories for plutext, page 2
# 2024-10-30 15:57:22,716 - INFO - Fetching repositories for plutext, page 3
# 2024-10-30 15:57:23,972 - INFO - Fetching repositories for Aisuko, page 1
# 2024-10-30 15:57:24,932 - INFO - Fetching repositories for dusterio, page 1
# 2024-10-30 15:59:11,381 - INFO - Fetching repositories for junhaow1, page 1
# 2024-10-30 15:59:12,360 - INFO - Fetching repositories for Gurenax, page 1
# 2024-10-30 15:59:13,872 - INFO - Fetching repositories for Gurenax, page 2
# 2024-10-30 15:59:15,560 - INFO - Fetching repositories for roachhd, page 1
# 2024-10-30 15:59:18,349 - INFO - Fetching repositories for roachhd, page 2
# 2024-10-30 15:59:20,845 - INFO - Fetching repositories for roachhd, page 3
# 2024-10-30 15:59:23,205 - INFO - Fetching repositories for roachhd, page 4
# 2024-10-30 15:59:25,941 - INFO - Fetching repositories for roachhd, page 5
# 2024-10-30 15:59:28,713 - INFO - Fetching repositories for vadmium, page 1
# 2024-10-30 15:59:30,075 - INFO - Fetching repositories for quad, page 1
# 2024-10-30 15:59:31,430 - INFO - Fetching repositories for danmacnish, page 1
# 2024-10-30 15:59:32,359 - INFO - Fetching repositories for mdub, page 1
# 2024-10-30 15:59:35,265 - INFO - Fetching repositories for mdub, page 2
# 2024-10-30 15:59:36,106 - INFO - Fetching repositories for 3xocyte, page 1
# 2024-10-30 15:59:36,936 - INFO - Fetching repositories for Gizmotronn, page 1
# 2024-10-30 15:59:39,129 - INFO - Fetching repositories for Gizmotronn, page 2
# 2024-10-30 15:59:40,004 - INFO - Fetching repositories for TheDen, page 1
# 2024-10-30 15:59:41,894 - INFO - Fetching repositories for TheDen, page 2
# 2024-10-30 15:59:42,792 - INFO - Fetching repositories for yinchuandong, page 1
# 2024-10-30 15:59:45,612 - INFO - Fetching repositories for yinchuandong, page 2
# 2024-10-30 15:59:46,824 - INFO - Fetching repositories for silviocesare, page 1
# 2024-10-30 15:59:48,103 - INFO - Fetching repositories for DungLai, page 1
# 2024-10-30 15:59:49,525 - INFO - Fetching repositories for tdmalone, page 1
# 2024-10-30 15:59:51,292 - INFO - Fetching repositories for ineffyble, page 1
# 2024-10-30 15:59:55,186 - INFO - Fetching repositories for ineffyble, page 2
# 2024-10-30 15:59:56,155 - INFO - Fetching repositories for Michelledng7, page 1
# 2024-10-30 15:59:57,945 - INFO - Fetching repositories for keeganstreet, page 1
# Scraped 337 users and 29237 repositories

# %%
import requests

GITHUB_TOKEN = "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"  
HEADERS = {"Authorization": f"token {GITHUB_TOKEN}"}

def get_top_users_in_melbourne():
    users = []
    query = "location:melbourne+followers:>100"
    page = 1
    per_page = 100

    while True:
        url = f"https://api.github.com/search/users?q={query}&per_page={per_page}&page={page}"
        response = requests.get(url, headers=HEADERS)
        
        if response.status_code != 200:
            print("Error fetching data:", response.json())
            break

        data = response.json()
        users.extend(data['items'])

        if len(data['items']) < per_page:
            break

        page += 1

    
    detailed_users = []
    for user in users:
        user_detail_url = user['url']
        user_detail_response = requests.get(user_detail_url, headers=HEADERS)
        if user_detail_response.status_code == 200:
            user_detail = user_detail_response.json()
            detailed_users.append({
                'login': user_detail['login'],
                'followers': user_detail['followers']
            })
        else:
            print(f"Error fetching user details for {user['login']}: {user_detail_response.json()}")

    # Sort users by followers count in descending order and get the top 5
    top_users = sorted(detailed_users, key=lambda x: x['followers'], reverse=True)[:5]
    return [user['login'] for user in top_users]

# Main process
if __name__ == "__main__":
    top_users = get_top_users_in_melbourne()
    print(", ".join(top_users))
# Out:
# mosh-hamedani, TheCherno, haileys, rstacruz, jesseduffield

# %%
#q2.
import requests
from datetime import datetime

GITHUB_TOKEN = "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"  
HEADERS = {"Authorization": f"token {GITHUB_TOKEN}"}

def get_earliest_users_in_melbourne():
    users = []
    query = "location:melbourne+followers:>100"
    page = 1
    per_page = 100

    while True:
        url = f"https://api.github.com/search/users?q={query}&per_page={per_page}&page={page}"
        response = requests.get(url, headers=HEADERS)
        
        if response.status_code != 200:
            print("Error fetching data:", response.json())
            break

        data = response.json()
        users.extend(data['items'])

        if len(data['items']) < per_page:
            break

        page += 1

  
    detailed_users = []
    for user in users:
        user_detail_url = user['url']
        user_detail_response = requests.get(user_detail_url, headers=HEADERS)
        if user_detail_response.status_code == 200:
            user_detail = user_detail_response.json()
            detailed_users.append({
                'login': user_detail['login'],
                'created_at': datetime.strptime(user_detail['created_at'], "%Y-%m-%dT%H:%M:%SZ")
            })
        else:
            print(f"Error fetching user details for {user['login']}: {user_detail_response.json()}")

    # Sort users by created_at date in ascending order and get the earliest 5
    earliest_users = sorted(detailed_users, key=lambda x: x['created_at'])[:5]
    return [user['login'] for user in earliest_users]

# Main process
if __name__ == "__main__":
    earliest_users = get_earliest_users_in_melbourne()
    print(", ".join(earliest_users))
# Out:
# toolmantim, crafterm, dgoodlad, Sutto, mdub

# %%
#q3.
import requests
from collections import Counter

GITHUB_TOKEN = "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"  
HEADERS = {"Authorization": f"token {GITHUB_TOKEN}"}

def get_users_in_melbourne():
    users = []
    query = "location:melbourne+followers:>100"
    page = 1
    per_page = 100

    while True:
        url = f"https://api.github.com/search/users?q={query}&per_page={per_page}&page={page}"
        response = requests.get(url, headers=HEADERS)

        if response.status_code != 200:
            print("Error fetching users:", response.json())
            break

        data = response.json()
        users.extend([user['login'] for user in data['items']])

        if len(data['items']) < per_page:
            break

        page += 1

    return users

def get_repositories_licenses(users):
    license_counter = Counter()

    for username in users:
        page = 1
        while True:
            url = f"https://api.github.com/users/{username}/repos?per_page=100&page={page}"
            response = requests.get(url, headers=HEADERS)
            if response.status_code != 200:
                print(f"Error fetching repos for {username}:", response.json())
                break

            repos = response.json()
            if not repos:
                break

           
            for repo in repos:
                license_name = repo['license']['key'] if repo.get('license') else None
                if license_name:
                    license_counter[license_name] += 1

            if len(repos) < 100:
                break

            page += 1

    
    top_licenses = [license for license, _ in license_counter.most_common(3)]
    return top_licenses


if __name__ == "__main__":
    users = get_users_in_melbourne()
    top_licenses = get_repositories_licenses(users)
    print(", ".join(top_licenses))
# Out:
# mit, other, apache-2.0

# %%
#q4import pandas as pd
from collections import Counter


users_df = pd.read_csv('users.csv')


company_counts = Counter(users_df['company'].dropna().str.strip().str.upper())

most_common_company = company_counts.most_common(1)


if most_common_company:
    print(f"The company with the majority of developers is: {most_common_company[0][0]}")
else:
    print("No company information available for majority analysis.")
# Out:
# The company with the majority of developers is: MONASH UNIVERSITY

# %%
#q5.
import pandas as pd
from collections import Counter


repos_df = pd.read_csv('repositories.csv')


language_counts = Counter(repos_df['language'].dropna())


most_common_language = language_counts.most_common(1)


if most_common_language:
    print(f"The most popular programming language is: {most_common_language[0][0]}")
else:
    print("No programming language information available for analysis.")
# Out:
# The most popular programming language is: JavaScript

# %%
#q6.
import pandas as pd
from collections import Counter


users_df = pd.read_csv('users.csv')
repos_df = pd.read_csv('repositories.csv')


users_after_2020 = users_df[pd.to_datetime(users_df['created_at']) > '2020-01-01']


repos_after_2020 = repos_df[repos_df['login'].isin(users_after_2020['login'])]


language_counts = Counter(repos_after_2020['language'].dropna())


second_most_common_language = language_counts.most_common(2)


if len(second_most_common_language) > 1:
    print(f"The second most popular programming language is: {second_most_common_language[1][0]}")
else:
    print("Not enough data to determine the second most popular programming language.")
# Out:
# The second most popular programming language is: JavaScript

# %%
#q7.
import pandas as pd


repos_df = pd.read_csv('repositories.csv')

repos_df = repos_df.dropna(subset=['language', 'stargazers_count'])


average_stars_per_language = repos_df.groupby('language')['stargazers_count'].mean()


top_language = average_stars_per_language.idxmax()
top_average_stars = average_stars_per_language.max()

print(f"The language with the highest average stars per repository is: {top_language} with an average of {top_average_stars:.2f} stars.")
# Out:
# The language with the highest average stars per repository is: D with an average of 2521.00 stars.

# %%
#q8.
import pandas as pd

# Load the user data
users_df = pd.read_csv('users.csv')


users_df['leader_strength'] = users_df['followers'] / (1 + users_df['following'])


top_leaders = users_df.sort_values(by='leader_strength', ascending=False).head(5)


top_leader_logins = top_leaders['login'].tolist()


print(", ".join(top_leader_logins))
# Out:
# mosh-hamedani, binarythistle, TheCherno, TuPayChain, rogerclarkmelbourne

# %%
#q9.
import pandas as pd


users_df = pd.read_csv('users.csv')


correlation = users_df['followers'].corr(users_df['public_repos'])


print(f"The correlation between the number of followers and public repositories is: {correlation:.3f}")
# Out:
# The correlation between the number of followers and public repositories is: 0.189

# %%
#q10.
import pandas as pd
import statsmodels.api as sm


users_df = pd.read_csv('users.csv')

X = users_df['public_repos']
y = users_df['followers']


X = sm.add_constant(X)


model = sm.OLS(y, X).fit()


summary = model.summary()


followers_per_repo = model.params['public_repos']
print(f"Estimated additional followers per additional public repository: {followers_per_repo:.3f}")


print(summary)
# Out:
# Estimated additional followers per additional public repository: 2.257
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              followers   R-squared:                       0.036
# Model:                            OLS   Adj. R-squared:                  0.033
# Method:                 Least Squares   F-statistic:                     12.46
# Date:                Wed, 30 Oct 2024   Prob (F-statistic):           0.000475
# Time:                        21:11:40   Log-Likelihood:                -2854.4
# No. Observations:                 337   AIC:                             5713.
# Df Residuals:                     335   BIC:                             5720.
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const          250.6959     84.633      2.962      0.003      84.217     417.174
# public_repos     2.2573      0.640      3.529      0.000       0.999       3.515
# ==============================================================================
# Omnibus:                      505.045   Durbin-Watson:                   0.112
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            73801.145
# Skew:                           7.805   Prob(JB):                         0.00
# Kurtosis:                      73.797   Cond. No.                         178.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#q11.
import pandas as pd


repos = pd.read_csv('repositories.csv')


repos['has_projects'] = repos['has_projects'].astype(int)
repos['has_wiki'] = repos['has_wiki'].astype(int)


correlation = repos['has_projects'].corr(repos['has_wiki'])


print(f"Correlation between having projects and having wiki: {correlation:.3f}")
# Out:
# Correlation between having projects and having wiki: 0.379

# %%
#q12.
import pandas as pd


users = pd.read_csv('users.csv')


average_hireable_following = users.loc[users['hireable'] == True, 'following'].mean()


average_non_hireable_following = users.loc[users['hireable'] == False, 'following'].mean()


difference = average_hireable_following - average_non_hireable_following


print(f"Difference in average following: {difference:.3f}")
# Out:
# Difference in average following: -46.186

# %%
#q13.
import pandas as pd
import numpy as np
import statsmodels.api as sm


users = pd.read_csv('users.csv')


users_with_bios = users[users['bio'].notnull() & (users['bio'].str.strip() != '')]


users_with_bios['bio_word_count'] = users_with_bios['bio'].apply(lambda x: len(x.split()))


X = users_with_bios['bio_word_count']
y = users_with_bios['followers']


X = sm.add_constant(X)


model = sm.OLS(y, X).fit()


slope = model.params['bio_word_count']


print(f"Slope of followers on bio word count: {slope:.3f}")
# Out:
# Slope of followers on bio word count: 7.708
# C:\Users\vidya\AppData\Local\Temp\ipykernel_6900\981175729.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   users_with_bios['bio_word_count'] = users_with_bios['bio'].apply(lambda x: len(x.split()))

# %%
#14.
import pandas as pd


repos = pd.read_csv('repositories.csv')


repos['created_at'] = pd.to_datetime(repos['created_at'])


repos['day_of_week'] = repos['created_at'].dt.dayofweek
weekend_repos = repos[repos['day_of_week'].isin([5, 6])]

user_repo_counts = weekend_repos['login'].value_counts()


top_users = user_repo_counts.head(5).index.tolist()


print(", ".join(top_users))
# Out:
# wolfeidau, karkranikhil, roachhd, plutext, rstacruz

# %%
#q15.
import pandas as pd


users = pd.read_csv('users.csv')


hireable_with_email = users[(users['hireable'] == True) & (users['email'].notna()) & (users['email'] != '')]
fraction_hireable_with_email = len(hireable_with_email) / len(users[users['hireable'] == True])


non_hireable_with_email = users[(users['hireable'] == False) & (users['email'].notna()) & (users['email'] != '')]
fraction_non_hireable_with_email = len(non_hireable_with_email) / len(users[users['hireable'] == False])

difference = fraction_hireable_with_email - fraction_non_hireable_with_email


print(f"Difference in email sharing (hireable - non-hireable): {difference:.3f}")
# Out:
# Difference in email sharing (hireable - non-hireable): 0.056

# %%
#q16.
import pandas as pd
from collections import Counter


users = pd.read_csv('users.csv')


surnames = users['name'].dropna().apply(lambda x: x.strip().split()[-1])


surname_counts = Counter(surnames)


max_count = max(surname_counts.values())


most_common_surnames = sorted([surname for surname, count in surname_counts.items() if count == max_count])


print(f"Most common surname(s): {', '.join(most_common_surnames)}")
# Out:
# Most common surname(s): Jackson, Wang
